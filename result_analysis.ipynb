# %% [markdown]
# ## Processed missing with MEAN

# %%
import numpy as np
import pickle 

k=0
range_of_dropout = [p/10 for p in range(0, 6)]
list_of_mean_val_losses = list()
list_of_mean_val_acc = list()
list_of_mean_train_losses = list()
list_of_mean_train_acc = list()

for dropout in range_of_dropout:
    with open('Results\\processed_missing\\mean\\dict_of_k_results_cv10_dropout-{}_3-layered_Adam_epochs_200_lr_0.001.pkl'
    .format(dropout), 'rb') as handle:
        dict_of_results = pickle.load(handle)
    
    print('Dropout rate: {}'.format(dropout))
    print('Estimated average val loss: {}'.format(np.mean(dict_of_results[k]['val_loss'])))
    print('Estimated average val acc: {}'.format(np.mean(dict_of_results[k]['val_acc'])))
    print('Estimated average val std acc: {}'.format(np.std(dict_of_results[k]['val_acc'])))
    print('Estimated average convergence time: {}'.format(np.mean(dict_of_results[k]['convergence_time'])))
    
    list_of_mean_train_acc.append(np.mean(dict_of_results[k]['train_acc']))
    list_of_mean_val_acc.append(np.mean(dict_of_results[k]['val_acc']))
    list_of_mean_train_losses.append(np.mean(dict_of_results[k]['train_loss']))
    list_of_mean_val_losses.append(np.mean(dict_of_results[k]['val_loss']))
    

list_of_mean_val_acc_processed_missing_mean = list_of_mean_val_acc
list_of_mean_val_loss_processed_missing_mean = list_of_mean_val_losses
# Out:
# Dropout rate: 0.0
# Estimated average val loss: 2.0860979938315545
# Estimated average val acc: 28.888888888888893
# Estimated average val std acc: 11.209441444756708
# Estimated average convergence time: 0:00:09.999933
# Dropout rate: 0.1
# Estimated average val loss: 1.9606275511406157
# Estimated average val acc: 32.037037037037045
# Estimated average val std acc: 12.07401726866892
# Estimated average convergence time: 0:00:10.286159
# Dropout rate: 0.2
# Estimated average val loss: 1.8801684347912768
# Estimated average val acc: 34.44444444444445
# Estimated average val std acc: 12.763903722054637
# Estimated average convergence time: 0:00:10.427272
# Dropout rate: 0.3
# Estimated average val loss: 1.8458184482872035
# Estimated average val acc: 35.648148148148145
# Estimated average val std acc: 13.473733528569674
# Estimated average convergence time: 0:00:10.505508
# Dropout rate: 0.4
# Estimated average val loss: 1.8398888247226608
# Estimated average val acc: 36.222222222222214
# Estimated average val std acc: 13.29810160033527
# Estimated average convergence time: 0:00:10.536480
# Dropout rate: 0.5
# Estimated average val loss: 1.8516533558563364
# Estimated average val acc: 36.97530864197531
# Estimated average val std acc: 13.293693934723986
# Estimated average convergence time: 0:00:10.545240

# %%
import matplotlib.pyplot as plt

plt.plot(range_of_dropout, list_of_mean_train_acc, label = "Train acc")
plt.plot(range_of_dropout, list_of_mean_val_acc, label = "Val acc")

plt.xlabel('Dropout rate')
plt.ylabel('Accuracy')
plt.gca().invert_xaxis()

plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(range_of_dropout, list_of_mean_train_losses, label = "Train loss")
plt.plot(range_of_dropout, list_of_mean_val_losses, label = "Val loss")

plt.xlabel('Dropout rate')
plt.ylabel('Mean Negative-Log Likelihood Loss')
plt.gca().invert_xaxis()

plt.legend()

# %% [markdown]
# ## Processed missing with ZERO_PADDING

# %%
import numpy as np
import pickle 

k=0
range_of_dropout = [p/10 for p in range(0, 6)]
list_of_mean_val_losses = list()
list_of_mean_val_acc = list()
list_of_mean_train_losses = list()
list_of_mean_train_acc = list()

for dropout in range_of_dropout:
    with open('Results\\processed_missing\\zero_padding\\dict_of_k_results_cv10_dropout-{}_3-layered_Adam_epochs_200_lr_0.001.pkl'
    .format(dropout), 'rb') as handle:
        dict_of_results = pickle.load(handle)
    
    print('Dropout rate: {}'.format(dropout))
    print('Estimated average val loss: {}'.format(np.mean(dict_of_results[k]['val_loss'])))
    print('Estimated average val acc: {}'.format(np.mean(dict_of_results[k]['val_acc'])))
    print('Estimated average val acc: {}'.format(np.mean(dict_of_results[k]['convergence_time'])))

    list_of_mean_train_acc.append(np.mean(dict_of_results[k]['train_acc']))
    list_of_mean_val_acc.append(np.mean(dict_of_results[k]['val_acc']))
    list_of_mean_train_losses.append(np.mean(dict_of_results[k]['train_loss']))
    list_of_mean_val_losses.append(np.mean(dict_of_results[k]['val_loss']))

list_of_mean_val_acc_processed_missing_zero_pad = list_of_mean_val_acc
list_of_mean_val_loss_processed_missing_zero_pad = list_of_mean_val_losses
# Out:
# Dropout rate: 0.0
# Estimated average val loss: 2.0682427100941294
# Estimated average val acc: 27.037037037037038
# Estimated average val acc: 0:00:10.194964
# Dropout rate: 0.1
# Estimated average val loss: 1.9130037695024182
# Estimated average val acc: 31.481481481481485
# Estimated average val acc: 0:00:10.359511
# Dropout rate: 0.2
# Estimated average val loss: 1.8298074109484908
# Estimated average val acc: 35.308641975308646
# Estimated average val acc: 0:00:10.392191
# Dropout rate: 0.3
# Estimated average val loss: 1.7886094319354435
# Estimated average val acc: 37.12962962962963
# Estimated average val acc: 0:00:10.384985
# Dropout rate: 0.4
# Estimated average val loss: 1.770289218811769
# Estimated average val acc: 38.370370370370374
# Estimated average val acc: 0:00:10.338968
# Dropout rate: 0.5
# Estimated average val loss: 1.7670101554628999
# Estimated average val acc: 38.51851851851851
# Estimated average val acc: 0:00:10.328444

# %%
import matplotlib.pyplot as plt

plt.plot(range_of_dropout, list_of_mean_train_acc, label = "Train acc")
plt.plot(range_of_dropout, list_of_mean_val_acc, label = "Val acc")

plt.xlabel('Dropout rate')
plt.ylabel('Accuracy')
plt.gca().invert_xaxis()

plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(range_of_dropout, list_of_mean_train_losses, label = "Train loss")
plt.plot(range_of_dropout, list_of_mean_val_losses, label = "Val loss")

plt.xlabel('Dropout rate')
plt.ylabel('Mean Negative-Log Likelihood Loss')
plt.gca().invert_xaxis()

plt.legend()

# %% [markdown]
# ## Processed missing with ZERO_PADDING and k-fold = 27

# %%
import numpy as np
import pickle 

k=0
range_of_dropout = [p/10 for p in range(0, 6)]
list_of_mean_val_losses = list()
list_of_mean_val_acc = list()
list_of_mean_train_losses = list()
list_of_mean_train_acc = list()

for dropout in range_of_dropout:
    with open('Results\\processed_missing\\zero_padding\\dict_of_k_results_cv27_dropout-{}_3-layered_Adam_epochs_200_lr_0.001.pkl'
    .format(dropout), 'rb') as handle:
        dict_of_results = pickle.load(handle)
    
    print('Dropout rate: {}'.format(dropout))
    print('Estimated average val loss: {}'.format(np.mean(dict_of_results[k]['val_loss'])))
    print('Estimated average val acc: {}'.format(np.mean(dict_of_results[k]['val_acc'])))
    print('Estimated average val std acc: {}'.format(np.std(dict_of_results[k]['val_acc'])))
    print('Estimated average convergence time: {}'.format(np.mean(dict_of_results[k]['convergence_time'])))
    
    list_of_mean_train_acc.append(np.mean(dict_of_results[k]['train_acc']))
    list_of_mean_val_acc.append(np.mean(dict_of_results[k]['val_acc']))
    list_of_mean_train_losses.append(np.mean(dict_of_results[k]['train_loss']))
    list_of_mean_val_losses.append(np.mean(dict_of_results[k]['val_loss']))
    

list_of_mean_val_acc_processed_missing_zero_pad_cv27 = list_of_mean_val_acc
list_of_mean_val_loss_processed_missing_zero_pad_cv27 = list_of_mean_val_losses
# Out:
# Dropout rate: 0.0
# Estimated average val loss: 0.8389520195507559
# Estimated average val acc: 72.5925925925926
# Estimated average val std acc: 12.35061629669116
# Estimated average convergence time: 0:00:08.283195
# Dropout rate: 0.1
# Estimated average val loss: 0.8046090734751404
# Estimated average val acc: 73.33333333333333
# Estimated average val std acc: 12.171612389003691
# Estimated average convergence time: 0:00:08.337521
# Dropout rate: 0.2
# Estimated average val loss: 0.7735994083648071
# Estimated average val acc: 74.5679012345679
# Estimated average val std acc: 13.151480479590889
# Estimated average convergence time: 0:00:08.371275
# Dropout rate: 0.3
# Estimated average val loss: 0.7549467649581193
# Estimated average val acc: 75.0925925925926
# Estimated average val std acc: 12.729040169974876
# Estimated average convergence time: 0:00:08.430400
# Dropout rate: 0.4
# Estimated average val loss: 0.7493904556833304
# Estimated average val acc: 74.5925925925926
# Estimated average val std acc: 13.430918611917248
# Estimated average convergence time: 0:00:08.469257
# Dropout rate: 0.5
# Estimated average val loss: 0.7594264037400575
# Estimated average val acc: 74.19753086419753
# Estimated average val std acc: 13.77636171314896
# Estimated average convergence time: 0:00:08.485596

# %%
import matplotlib.pyplot as plt

plt.plot(range_of_dropout, list_of_mean_train_acc, label = "Train acc")
plt.plot(range_of_dropout, list_of_mean_val_acc, label = "Val acc")

plt.xlabel('Dropout rate')
plt.ylabel('Accuracy')
plt.gca().invert_xaxis()

plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(range_of_dropout, list_of_mean_train_losses, label = "Train loss")
plt.plot(range_of_dropout, list_of_mean_val_losses, label = "Val loss")

plt.xlabel('Dropout rate')
plt.ylabel('Mean Negative-Log Likelihood Loss')
plt.gca().invert_xaxis()

plt.legend()

# %% [markdown]
# ## Segmentation with k=5 and NO FILLING OF MISSING DATA
# ### Raw data with segmentation

# %%
## Results for Segmentation with k=5

import numpy as np
import pickle 

k = 5
range_of_dropout = [p/10 for p in range(0, 6)]
list_of_mean_val_losses = list()
list_of_mean_val_acc = list()
list_of_mean_train_losses = list()
list_of_mean_train_acc = list()

for dropout in range_of_dropout:
    with open('Results\\segmentation\\no_filling_missing\\dict_of_k_results_cv10_dropout-{}_3-layered_Adam_epochs_200_lr_0.001.pkl'
    .format(dropout), 'rb') as handle:
        dict_of_results = pickle.load(handle)
    
    print('Dropout rate: {}'.format(dropout))
    print('Estimated average val loss: {}'.format(np.mean(dict_of_results[k]['val_loss'])))
    print('Estimated average val acc: {}'.format(np.mean(dict_of_results[k]['val_acc'])))
    print('Estimated average val acc: {}'.format(np.mean(dict_of_results[k]['convergence_time'])))
    

    list_of_mean_train_acc.append(np.mean(dict_of_results[k]['train_acc']))
    list_of_mean_val_acc.append(np.mean(dict_of_results[k]['val_acc']))
    list_of_mean_train_losses.append(np.mean(dict_of_results[k]['train_loss']))
    list_of_mean_val_losses.append(np.mean(dict_of_results[k]['val_loss']))

list_of_mean_val_acc_segmentation_raw_data = list_of_mean_val_acc
list_of_mean_val_loss_segmentation_raw_data = list_of_mean_val_losses
# Out:
# Dropout rate: 0.0
# Estimated average val loss: 3.5371690012162027
# Estimated average val acc: 22.962962962962962
# Estimated average val acc: 0:00:09.873209
# Dropout rate: 0.1
# Estimated average val loss: 3.2541040316841157
# Estimated average val acc: 21.481481481481485
# Estimated average val acc: 0:00:09.950746
# Dropout rate: 0.2
# Estimated average val loss: 2.978753609202732
# Estimated average val acc: 22.96296296296296
# Estimated average val acc: 0:00:10.006451
# Dropout rate: 0.3
# Estimated average val loss: 2.7683670461839425
# Estimated average val acc: 24.35185185185185
# Estimated average val acc: 0:00:09.977835
# Dropout rate: 0.4
# Estimated average val loss: 2.662129602741309
# Estimated average val acc: 25.407407407407405
# Estimated average val acc: 0:00:09.980966
# Dropout rate: 0.5
# Estimated average val loss: 2.5465250475987746
# Estimated average val acc: 26.790123456790116
# Estimated average val acc: 0:00:09.967601

# %%
import matplotlib.pyplot as plt

plt.plot(range_of_dropout, list_of_mean_train_acc, label = "Train acc")
plt.plot(range_of_dropout, list_of_mean_val_acc, label = "Val acc")

plt.xlabel('Dropout rate')
plt.ylabel('Accuracy')
plt.gca().invert_xaxis()

plt.legend()
plt.title('Segmentation k=5 no filling missing data')
# Out:
# Text(0.5, 1.0, 'Segmentation k=5 no filling missing data')

# %%
import matplotlib.pyplot as plt
reversed_dropouts = range_of_dropout[::-1]

plt.plot(range_of_dropout, list_of_mean_train_losses, label = "Train loss")
plt.plot(range_of_dropout, list_of_mean_val_losses, label = "Val loss")

plt.xlabel('Dropout rate')
plt.ylabel('Mean Negative-Log Likelihood Loss')
plt.gca().invert_xaxis()
plt.legend()
plt.title('Segmentation k=5 no filling missing data')
# Out:
# Text(0.5, 1.0, 'Segmentation k=5 no filling missing data')

# %% [markdown]
# ## Segmentation with k=5 and FILLED MISSING DATA WITH ZERO PADDING

# %%
## Results for Segmentation with k=5

import numpy as np
import pickle 

k = 5
range_of_dropout = [p/10 for p in range(0, 6)]
list_of_mean_val_losses = list()
list_of_mean_val_acc = list()
list_of_mean_train_losses = list()
list_of_mean_train_acc = list()

for dropout in range_of_dropout:
    with open('Results\\segmentation\\zero_padding\\dict_of_k_results_cv10_dropout-{}_3-layered_Adam_epochs_200_lr_0.001.pkl'
    .format(dropout), 'rb') as handle:
        dict_of_results = pickle.load(handle)
    
    print('Dropout rate: {}'.format(dropout))
    print('Estimated average val loss: {}'.format(np.mean(dict_of_results[k]['val_loss'])))
    print('Estimated average val acc: {}'.format(np.mean(dict_of_results[k]['val_acc'])))
    print('Estimated average val acc: {}'.format(np.mean(dict_of_results[k]['convergence_time'])))

    list_of_mean_train_acc.append(np.mean(dict_of_results[k]['train_acc']))
    list_of_mean_val_acc.append(np.mean(dict_of_results[k]['val_acc']))
    list_of_mean_train_losses.append(np.mean(dict_of_results[k]['train_loss']))
    list_of_mean_val_losses.append(np.mean(dict_of_results[k]['val_loss']))

list_of_mean_val_acc_segmentation_filled_zero_pad = list_of_mean_val_acc
list_of_mean_val_loss_segmentation_filled_zero_pad = list_of_mean_val_losses
# Out:
# Dropout rate: 0.0
# Estimated average val loss: 3.2515520086698038
# Estimated average val acc: 20.74074074074074
# Estimated average val acc: 0:00:09.548176
# Dropout rate: 0.1
# Estimated average val loss: 2.7469764608126286
# Estimated average val acc: 24.25925925925926
# Estimated average val acc: 0:00:09.838799
# Dropout rate: 0.2
# Estimated average val loss: 2.5502795806058693
# Estimated average val acc: 27.037037037037035
# Estimated average val acc: 0:00:09.927534
# Dropout rate: 0.3
# Estimated average val loss: 2.398340995492253
# Estimated average val acc: 28.611111111111107
# Estimated average val acc: 0:00:09.792129
# Dropout rate: 0.4
# Estimated average val loss: 2.3008664885460353
# Estimated average val acc: 29.703703703703706
# Estimated average val acc: 0:00:09.691797
# Dropout rate: 0.5
# Estimated average val loss: 2.2330485795235626
# Estimated average val acc: 30.432098765432094
# Estimated average val acc: 0:00:09.642406

# %%
import matplotlib.pyplot as plt

plt.plot(range_of_dropout, list_of_mean_train_acc, label = "Train acc")
plt.plot(range_of_dropout, list_of_mean_val_acc, label = "Val acc")

plt.xlabel('Dropout rate')
plt.ylabel('Accuracy')
plt.gca().invert_xaxis()

plt.legend()
plt.title('Segmentation k=5 filled zero padding')
# Out:
# Text(0.5, 1.0, 'Segmentation k=5 filled zero padding')

# %%
import matplotlib.pyplot as plt
reversed_dropouts = range_of_dropout[::-1]

plt.plot(range_of_dropout, list_of_mean_train_losses, label = "Train loss")
plt.plot(range_of_dropout, list_of_mean_val_losses, label = "Val loss")

plt.xlabel('Dropout rate')
plt.ylabel('Mean Negative-Log Likelihood Loss')
plt.gca().invert_xaxis()

plt.legend()
plt.title('Segmentation k=5 filled zero padding')
# Out:
# Text(0.5, 1.0, 'Segmentation k=5 filled zero padding')

# %% [markdown]
# ## Comparison between methods on validation set

# %%
import matplotlib.pyplot as plt

plt.plot(range_of_dropout, list_of_mean_val_acc_processed_missing_mean, label = "Processed missing data - mean")
plt.plot(range_of_dropout, list_of_mean_val_acc_processed_missing_zero_pad, label = "Processed missing data - zero pad")
plt.plot(range_of_dropout, list_of_mean_val_acc_segmentation_raw_data, label = "Segmentation k=5 - raw data")
plt.plot(range_of_dropout, list_of_mean_val_acc_segmentation_filled_zero_pad, label = "Segmentation k=5 - filled missing zero pad")
plt.plot(range_of_dropout, list_of_mean_val_acc_processed_missing_zero_pad_cv27, label = "Processed missing data - zero pad cv27")

plt.xlabel('Dropout rate')
plt.ylabel('Accuracy')
plt.gca().invert_xaxis()

plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(range_of_dropout, list_of_mean_val_loss_processed_missing_mean, label = "Processed missing data - mean")
plt.plot(range_of_dropout, list_of_mean_val_loss_processed_missing_zero_pad, label = "Processed missing data - zero pad")
plt.plot(range_of_dropout, list_of_mean_val_loss_segmentation_raw_data, label = "Segmentation k=5 - raw data")
plt.plot(range_of_dropout, list_of_mean_val_loss_segmentation_filled_zero_pad, label = "Segmentation k=5 - filled missing zero pad")
plt.plot(range_of_dropout, list_of_mean_val_loss_processed_missing_zero_pad_cv27, label = "Processed missing data - zero pad cv27")

plt.xlabel('Dropout rate')
plt.ylabel('Mean Negative-Log Likelihood Loss')
plt.gca().invert_xaxis()

plt.legend()
