# %% [markdown]
# ## Processed missing with MEAN

# %%
import numpy as np
import pickle 

k=0
range_of_dropout = [p/10 for p in range(0, 6)]
list_of_mean_val_losses = list()
list_of_mean_val_acc = list()
list_of_mean_train_losses = list()
list_of_mean_train_acc = list()

for dropout in range_of_dropout:
    with open('Results\\processed_missing\\mean\\dict_of_k_results_cv10_dropout-{}_3-layered_Adam.pkl'
    .format(dropout), 'rb') as handle:
        dict_of_results = pickle.load(handle)
    
    print('Dropout rate: {}'.format(dropout))
    print('Estimated average val loss: {}'.format(np.mean(dict_of_results[k]['val_loss'])))
    print('Estimated average val acc: {}'.format(np.mean(dict_of_results[k]['val_acc'])))

    list_of_mean_train_acc.append(np.mean(dict_of_results[k]['train_acc']))
    list_of_mean_val_acc.append(np.mean(dict_of_results[k]['val_acc']))
    list_of_mean_train_losses.append(np.mean(dict_of_results[k]['train_loss']))
    list_of_mean_val_losses.append(np.mean(dict_of_results[k]['val_loss']))
# Out:
# Dropout rate: 0.0
# Estimated average val loss: 0.4567613754966965
# Estimated average val acc: 83.86372164655893
# Dropout rate: 0.1
# Estimated average val loss: 0.3384018586335124
# Estimated average val acc: 89.50156279044488
# Dropout rate: 0.2
# Estimated average val loss: 0.313513216754232
# Estimated average val acc: 89.65740202847763
# Dropout rate: 0.3
# Estimated average val loss: 0.3408771662573605
# Estimated average val acc: 88.02372323518871
# Dropout rate: 0.4
# Estimated average val loss: 0.3450055496354109
# Estimated average val acc: 87.62596764524989
# Dropout rate: 0.5
# Estimated average val loss: 0.3396299042645708
# Estimated average val acc: 87.53885102015634

# %%
import matplotlib.pyplot as plt

plt.plot(range_of_dropout, list_of_mean_train_acc, label = "Train acc")
plt.plot(range_of_dropout, list_of_mean_val_acc, label = "Val acc")

plt.xlabel('Dropout rate')
plt.ylabel('Accuracy')
plt.gca().invert_xaxis()

plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(range_of_dropout, list_of_mean_train_losses, label = "Train loss")
plt.plot(range_of_dropout, list_of_mean_val_losses, label = "Val loss")

plt.xlabel('Dropout rate')
plt.ylabel('Mean Negative-Log Likelihood Loss')
plt.gca().invert_xaxis()

plt.legend()

# %% [markdown]
# ## Processed missing with ZERO_PADDING

# %%
import numpy as np
import pickle 

k=0
range_of_dropout = [p/10 for p in range(0, 6)]
list_of_mean_val_losses = list()
list_of_mean_val_acc = list()
list_of_mean_train_losses = list()
list_of_mean_train_acc = list()

for dropout in range_of_dropout:
    with open('Results\\processed_missing\\zero_padding\\dict_of_k_results_cv10_dropout-{}_3-layered_Adam.pkl'
    .format(dropout), 'rb') as handle:
        dict_of_results = pickle.load(handle)
    
    print('Dropout rate: {}'.format(dropout))
    print('Estimated average val loss: {}'.format(np.mean(dict_of_results[k]['val_loss'])))
    print('Estimated average val acc: {}'.format(np.mean(dict_of_results[k]['val_acc'])))

    list_of_mean_train_acc.append(np.mean(dict_of_results[k]['train_acc']))
    list_of_mean_val_acc.append(np.mean(dict_of_results[k]['val_acc']))
    list_of_mean_train_losses.append(np.mean(dict_of_results[k]['train_loss']))
    list_of_mean_val_losses.append(np.mean(dict_of_results[k]['val_loss']))
# Out:
# Dropout rate: 0.0
# Estimated average val loss: 0.4129472843867288
# Estimated average val acc: 85.58580924722607
# Dropout rate: 0.1
# Estimated average val loss: 0.34684612559548633
# Estimated average val acc: 87.84262811931197
# Dropout rate: 0.2
# Estimated average val loss: 0.3208793071306172
# Estimated average val acc: 88.67824052155925
# Dropout rate: 0.3
# Estimated average val loss: 0.30264684714702533
# Estimated average val acc: 89.60710866470353
# Dropout rate: 0.4
# Estimated average val loss: 0.2984798602789469
# Estimated average val acc: 89.72752432083433
# Dropout rate: 0.5
# Estimated average val loss: 0.30082681079564877
# Estimated average val acc: 89.52369655558306

# %%
import matplotlib.pyplot as plt

plt.plot(range_of_dropout, list_of_mean_train_acc, label = "Train acc")
plt.plot(range_of_dropout, list_of_mean_val_acc, label = "Val acc")

plt.xlabel('Dropout rate')
plt.ylabel('Accuracy')
plt.gca().invert_xaxis()

plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(range_of_dropout, list_of_mean_train_losses, label = "Train loss")
plt.plot(range_of_dropout, list_of_mean_val_losses, label = "Val loss")

plt.xlabel('Dropout rate')
plt.ylabel('Mean Negative-Log Likelihood Loss')
plt.gca().invert_xaxis()

plt.legend()

# %% [markdown]
# ## Segmentation with k=5 and NO FILLING OF MISSING DATA
# ### Raw data with segmentation

# %%
## Results for Segmentation with k=5

import numpy as np
import pickle 

k = 5
range_of_dropout = [p/10 for p in range(0, 6)]
list_of_mean_val_losses = list()
list_of_mean_val_acc = list()
list_of_mean_train_losses = list()
list_of_mean_train_acc = list()

for dropout in range_of_dropout:
    with open('Results\\segmentation\\no_filling_missing\\dict_of_k_results_cv10_dropout-{}_3-layered_Adam.pkl'
    .format(dropout), 'rb') as handle:
        dict_of_results = pickle.load(handle)
    
    print('Dropout rate: {}'.format(dropout))
    print('Estimated average val loss: {}'.format(np.mean(dict_of_results[k]['val_loss'])))
    print('Estimated average val acc: {}'.format(np.mean(dict_of_results[k]['val_acc'])))

    list_of_mean_train_acc.append(np.mean(dict_of_results[k]['train_acc']))
    list_of_mean_val_acc.append(np.mean(dict_of_results[k]['val_acc']))
    list_of_mean_train_losses.append(np.mean(dict_of_results[k]['train_loss']))
    list_of_mean_val_losses.append(np.mean(dict_of_results[k]['val_loss']))
# Out:
# Dropout rate: 0.0
# Estimated average val loss: 1.0781911451582398
# Estimated average val acc: 68.13801783402009
# Dropout rate: 0.1
# Estimated average val loss: 0.8875146007648592
# Estimated average val acc: 73.30153457793527
# Dropout rate: 0.2
# Estimated average val loss: 0.6924976267153194
# Estimated average val acc: 78.69730235896434
# Dropout rate: 0.3
# Estimated average val loss: 0.7981755465782576
# Estimated average val acc: 76.02765398869603
# Dropout rate: 0.4
# Estimated average val loss: 0.7314637256032048
# Estimated average val acc: 76.91655162071166
# Dropout rate: 0.5
# Estimated average val loss: 0.873736455298384
# Estimated average val acc: 73.10237211308318

# %%
import matplotlib.pyplot as plt

plt.plot(range_of_dropout, list_of_mean_train_acc, label = "Train acc")
plt.plot(range_of_dropout, list_of_mean_val_acc, label = "Val acc")

plt.xlabel('Dropout rate')
plt.ylabel('Accuracy')
plt.gca().invert_xaxis()

plt.legend()

# %%
import matplotlib.pyplot as plt
reversed_dropouts = range_of_dropout[::-1]

plt.plot(range_of_dropout, list_of_mean_train_losses, label = "Train loss")
plt.plot(range_of_dropout, list_of_mean_val_losses, label = "Val loss")

plt.xlabel('Dropout rate')
plt.ylabel('Mean Negative-Log Likelihood Loss')
plt.gca().invert_xaxis()
plt.legend()

# %% [markdown]
# ## Segmentation with k=5 and FILLED MISSING DATA WITH MEAN

# %%
## Results for Segmentation with k=5

import numpy as np
import pickle 

k = 5
range_of_dropout = [p/10 for p in range(0, 6)]
list_of_mean_val_losses = list()
list_of_mean_val_acc = list()
list_of_mean_train_losses = list()
list_of_mean_train_acc = list()

for dropout in range_of_dropout:
    with open('Results\\segmentation\\mean\\dict_of_k_results_cv10_dropout-{}_3-layered_Adam.pkl'
    .format(dropout), 'rb') as handle:
        dict_of_results = pickle.load(handle)
    
    print('Dropout rate: {}'.format(dropout))
    print('Estimated average val loss: {}'.format(np.mean(dict_of_results[k]['val_loss'])))
    print('Estimated average val acc: {}'.format(np.mean(dict_of_results[k]['val_acc'])))

    list_of_mean_train_acc.append(np.mean(dict_of_results[k]['train_acc']))
    list_of_mean_val_acc.append(np.mean(dict_of_results[k]['val_acc']))
    list_of_mean_train_losses.append(np.mean(dict_of_results[k]['train_loss']))
    list_of_mean_val_losses.append(np.mean(dict_of_results[k]['val_loss']))

# %%
import matplotlib.pyplot as plt

plt.plot(range_of_dropout, list_of_mean_train_acc, label = "Train acc")
plt.plot(range_of_dropout, list_of_mean_val_acc, label = "Val acc")

plt.xlabel('Dropout rate')
plt.ylabel('Accuracy')
plt.gca().invert_xaxis()

plt.legend()

# %%
import matplotlib.pyplot as plt
reversed_dropouts = range_of_dropout[::-1]

plt.plot(range_of_dropout, list_of_mean_train_losses, label = "Train loss")
plt.plot(range_of_dropout, list_of_mean_val_losses, label = "Val loss")

plt.xlabel('Dropout rate')
plt.ylabel('Mean Negative-Log Likelihood Loss')
plt.gca().invert_xaxis()
plt.legend()
